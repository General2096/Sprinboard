# %%
# !pip install gdcm
# !pip install fastbook
# !pip install pylibjpeg-libjpeg
# !pip install pylibjpeg
# Out:
# Collecting gdcm
#   Downloading gdcm-1.1-py3-none-manylinux1_x86_64.whl (2.7 MB)
#      |████████████████████████████████| 2.7 MB 28.6 MB/s eta 0:00:01
# Installing collected packages: gdcm
# Successfully installed gdcm-1.1
# Collecting fastbook
#   Downloading fastbook-0.0.18-py3-none-any.whl (720 kB)
#      |████████████████████████████████| 720 kB 27.4 MB/s eta 0:00:01
# Requirement already satisfied: pandas in /opt/conda/lib/python3.7/site-packages (from fastbook) (1.3.4)
# Requirement already satisfied: sentencepiece in /opt/conda/lib/python3.7/site-packages (from fastbook) (0.1.86)
# Requirement already satisfied: pip in /opt/conda/lib/python3.7/site-packages (from fastbook) (21.0.1)
# Requirement already satisfied: ipywidgets in /opt/conda/lib/python3.7/site-packages (from fastbook) (7.6.5)
# Requirement already satisfied: fastai>=2.5 in /opt/conda/lib/python3.7/site-packages (from fastbook) (2.5.4)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.7/site-packages (from fastbook) (21.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.7/site-packages (from fastbook) (2.25.1)
# Requirement already satisfied: nbdev>=0.2.38 in /opt/conda/lib/python3.7/site-packages (from fastbook) (1.1.23)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in /opt/conda/lib/python3.7/site-packages (from fastai>=2.5->fastbook) (0.0.5)
# Requirement already satisfied: pillow>6.0.0 in /opt/conda/lib/python3.7/site-packages (from fastai>=2.5->fastbook) (8.4.0)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.7/site-packages (from fastai>=2.5->fastbook) (1.7.2)
# Requirement already satisfied: torchvision>=0.8.2 in /opt/conda/lib/python3.7/site-packages (from fastai>=2.5->fastbook) (0.11.0)
# Requirement already satisfied: fastprogress>=0.2.4 in /opt/conda/lib/python3.7/site-packages (from fastai>=2.5->fastbook) (1.0.0)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.7/site-packages (from fastai>=2.5->fastbook) (1.0.1)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.7/site-packages (from fastai>=2.5->fastbook) (3.4.3)
# Requirement already satisfied: spacy<4 in /opt/conda/lib/python3.7/site-packages (from fastai>=2.5->fastbook) (3.2.0)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.7/site-packages (from fastai>=2.5->fastbook) (5.4.1)
# Requirement already satisfied: torch<1.11,>=1.7.0 in /opt/conda/lib/python3.7/site-packages (from fastai>=2.5->fastbook) (1.10.0)
# Requirement already satisfied: fastcore<1.4,>=1.3.27 in /opt/conda/lib/python3.7/site-packages (from fastai>=2.5->fastbook) (1.3.28)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from fastprogress>=0.2.4->fastai>=2.5->fastbook) (1.21.2)
# Requirement already satisfied: jupyter in /opt/conda/lib/python3.7/site-packages (from nbdev>=0.2.38->fastbook) (1.0.0)
# Requirement already satisfied: nbconvert<6 in /opt/conda/lib/python3.7/site-packages (from nbdev>=0.2.38->fastbook) (5.6.1)
# Requirement already satisfied: fastrelease in /opt/conda/lib/python3.7/site-packages (from nbdev>=0.2.38->fastbook) (0.1.12)
# Requirement already satisfied: ipykernel in /opt/conda/lib/python3.7/site-packages (from nbdev>=0.2.38->fastbook) (6.5.0)
# Requirement already satisfied: nbformat>=4.4.0 in /opt/conda/lib/python3.7/site-packages (from nbdev>=0.2.38->fastbook) (5.1.3)
# Requirement already satisfied: ghapi in /opt/conda/lib/python3.7/site-packages (from nbdev>=0.2.38->fastbook) (0.1.19)
# Requirement already satisfied: jupyter-client<7.0 in /opt/conda/lib/python3.7/site-packages (from nbdev>=0.2.38->fastbook) (6.1.12)
# Requirement already satisfied: tornado>=4.1 in /opt/conda/lib/python3.7/site-packages (from jupyter-client<7.0->nbdev>=0.2.38->fastbook) (6.1)
# Requirement already satisfied: jupyter-core>=4.6.0 in /opt/conda/lib/python3.7/site-packages (from jupyter-client<7.0->nbdev>=0.2.38->fastbook) (4.9.1)
# Requirement already satisfied: python-dateutil>=2.1 in /opt/conda/lib/python3.7/site-packages (from jupyter-client<7.0->nbdev>=0.2.38->fastbook) (2.8.2)
# Requirement already satisfied: traitlets in /opt/conda/lib/python3.7/site-packages (from jupyter-client<7.0->nbdev>=0.2.38->fastbook) (5.1.0)
# Requirement already satisfied: pyzmq>=13 in /opt/conda/lib/python3.7/site-packages (from jupyter-client<7.0->nbdev>=0.2.38->fastbook) (22.3.0)
# Requirement already satisfied: jinja2>=2.4 in /opt/conda/lib/python3.7/site-packages (from nbconvert<6->nbdev>=0.2.38->fastbook) (2.11.3)
# Requirement already satisfied: bleach in /opt/conda/lib/python3.7/site-packages (from nbconvert<6->nbdev>=0.2.38->fastbook) (4.1.0)
# Requirement already satisfied: defusedxml in /opt/conda/lib/python3.7/site-packages (from nbconvert<6->nbdev>=0.2.38->fastbook) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /opt/conda/lib/python3.7/site-packages (from nbconvert<6->nbdev>=0.2.38->fastbook) (0.8.4)
# Requirement already satisfied: testpath in /opt/conda/lib/python3.7/site-packages (from nbconvert<6->nbdev>=0.2.38->fastbook) (0.5.0)
# Requirement already satisfied: pygments in /opt/conda/lib/python3.7/site-packages (from nbconvert<6->nbdev>=0.2.38->fastbook) (2.10.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /opt/conda/lib/python3.7/site-packages (from nbconvert<6->nbdev>=0.2.38->fastbook) (0.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/lib/python3.7/site-packages (from nbconvert<6->nbdev>=0.2.38->fastbook) (1.5.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/lib/python3.7/site-packages (from jinja2>=2.4->nbconvert<6->nbdev>=0.2.38->fastbook) (2.0.1)
# Requirement already satisfied: ipython-genutils in /opt/conda/lib/python3.7/site-packages (from nbformat>=4.4.0->nbdev>=0.2.38->fastbook) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /opt/conda/lib/python3.7/site-packages (from nbformat>=4.4.0->nbdev>=0.2.38->fastbook) (3.2.0)
# Requirement already satisfied: six>=1.11.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4.0->nbdev>=0.2.38->fastbook) (1.16.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4.0->nbdev>=0.2.38->fastbook) (58.0.4)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4.0->nbdev>=0.2.38->fastbook) (21.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4.0->nbdev>=0.2.38->fastbook) (0.18.0)
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4.0->nbdev>=0.2.38->fastbook) (4.8.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/conda/lib/python3.7/site-packages (from spacy<4->fastai>=2.5->fastbook) (4.61.2)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /opt/conda/lib/python3.7/site-packages (from spacy<4->fastai>=2.5->fastbook) (8.0.13)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /opt/conda/lib/python3.7/site-packages (from spacy<4->fastai>=2.5->fastbook) (3.0.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /opt/conda/lib/python3.7/site-packages (from spacy<4->fastai>=2.5->fastbook) (2.4.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /opt/conda/lib/python3.7/site-packages (from spacy<4->fastai>=2.5->fastbook) (1.8.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from spacy<4->fastai>=2.5->fastbook) (3.0.6)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /opt/conda/lib/python3.7/site-packages (from spacy<4->fastai>=2.5->fastbook) (3.10.0.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/conda/lib/python3.7/site-packages (from spacy<4->fastai>=2.5->fastbook) (2.0.6)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /opt/conda/lib/python3.7/site-packages (from spacy<4->fastai>=2.5->fastbook) (3.3.0)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /opt/conda/lib/python3.7/site-packages (from spacy<4->fastai>=2.5->fastbook) (0.7.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/conda/lib/python3.7/site-packages (from spacy<4->fastai>=2.5->fastbook) (2.0.6)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/conda/lib/python3.7/site-packages (from spacy<4->fastai>=2.5->fastbook) (1.0.1)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /opt/conda/lib/python3.7/site-packages (from spacy<4->fastai>=2.5->fastbook) (0.4.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/conda/lib/python3.7/site-packages (from spacy<4->fastai>=2.5->fastbook) (1.0.6)
# Requirement already satisfied: pathy>=0.3.5 in /opt/conda/lib/python3.7/site-packages (from spacy<4->fastai>=2.5->fastbook) (0.6.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /opt/conda/lib/python3.7/site-packages (from spacy<4->fastai>=2.5->fastbook) (0.8.2)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from catalogue<2.1.0,>=2.0.6->spacy<4->fastai>=2.5->fastbook) (3.6.0)
# Requirement already satisfied: pyparsing<3,>=2.0.2 in /opt/conda/lib/python3.7/site-packages (from packaging->fastbook) (2.4.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /opt/conda/lib/python3.7/site-packages (from pathy>=0.3.5->spacy<4->fastai>=2.5->fastbook) (5.2.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests->fastbook) (1.26.6)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests->fastbook) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests->fastbook) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests->fastbook) (4.0.0)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /opt/conda/lib/python3.7/site-packages (from typer<0.5.0,>=0.3.0->spacy<4->fastai>=2.5->fastbook) (8.0.3)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.7/site-packages (from bleach->nbconvert<6->nbdev>=0.2.38->fastbook) (0.5.1)
# Requirement already satisfied: argcomplete>=1.12.3 in /opt/conda/lib/python3.7/site-packages (from ipykernel->nbdev>=0.2.38->fastbook) (1.12.3)
# Requirement already satisfied: ipython<8.0,>=7.23.1 in /opt/conda/lib/python3.7/site-packages (from ipykernel->nbdev>=0.2.38->fastbook) (7.27.0)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /opt/conda/lib/python3.7/site-packages (from ipykernel->nbdev>=0.2.38->fastbook) (1.5.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /opt/conda/lib/python3.7/site-packages (from ipykernel->nbdev>=0.2.38->fastbook) (0.1.2)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.7/site-packages (from ipython<8.0,>=7.23.1->ipykernel->nbdev>=0.2.38->fastbook) (5.1.0)
# Requirement already satisfied: backcall in /opt/conda/lib/python3.7/site-packages (from ipython<8.0,>=7.23.1->ipykernel->nbdev>=0.2.38->fastbook) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from ipython<8.0,>=7.23.1->ipykernel->nbdev>=0.2.38->fastbook) (3.0.20)
# Requirement already satisfied: pickleshare in /opt/conda/lib/python3.7/site-packages (from ipython<8.0,>=7.23.1->ipykernel->nbdev>=0.2.38->fastbook) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.7/site-packages (from ipython<8.0,>=7.23.1->ipykernel->nbdev>=0.2.38->fastbook) (0.18.0)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.7/site-packages (from ipython<8.0,>=7.23.1->ipykernel->nbdev>=0.2.38->fastbook) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/conda/lib/python3.7/site-packages (from jedi>=0.16->ipython<8.0,>=7.23.1->ipykernel->nbdev>=0.2.38->fastbook) (0.8.2)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.7/site-packages (from pexpect>4.3->ipython<8.0,>=7.23.1->ipykernel->nbdev>=0.2.38->fastbook) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<8.0,>=7.23.1->ipykernel->nbdev>=0.2.38->fastbook) (0.2.5)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /opt/conda/lib/python3.7/site-packages (from ipywidgets->fastbook) (1.0.2)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /opt/conda/lib/python3.7/site-packages (from ipywidgets->fastbook) (3.5.2)
# Requirement already satisfied: notebook>=4.4.1 in /opt/conda/lib/python3.7/site-packages (from widgetsnbextension~=3.5.0->ipywidgets->fastbook) (6.4.5)
# Requirement already satisfied: argon2-cffi in /opt/conda/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->fastbook) (21.1.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in /opt/conda/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->fastbook) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /opt/conda/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->fastbook) (0.12.1)
# Requirement already satisfied: prometheus-client in /opt/conda/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->fastbook) (0.12.0)
# Requirement already satisfied: cffi>=1.0.0 in /opt/conda/lib/python3.7/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->fastbook) (1.14.6)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.7/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->fastbook) (2.20)
# Requirement already satisfied: qtconsole in /opt/conda/lib/python3.7/site-packages (from jupyter->nbdev>=0.2.38->fastbook) (5.2.0)
# Requirement already satisfied: jupyter-console in /opt/conda/lib/python3.7/site-packages (from jupyter->nbdev>=0.2.38->fastbook) (6.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib->fastai>=2.5->fastbook) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.7/site-packages (from matplotlib->fastai>=2.5->fastbook) (0.11.0)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.7/site-packages (from pandas->fastbook) (2021.3)
# Requirement already satisfied: qtpy in /opt/conda/lib/python3.7/site-packages (from qtconsole->jupyter->nbdev>=0.2.38->fastbook) (1.11.2)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/lib/python3.7/site-packages (from scikit-learn->fastai>=2.5->fastbook) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from scikit-learn->fastai>=2.5->fastbook) (3.0.0)
# Installing collected packages: fastbook
# Successfully installed fastbook-0.0.18
# Collecting pylibjpeg-libjpeg
#   Downloading pylibjpeg_libjpeg-1.3.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
#      |████████████████████████████████| 4.3 MB 29.1 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.20 in /opt/conda/lib/python3.7/site-packages (from pylibjpeg-libjpeg) (1.21.2)
# Installing collected packages: pylibjpeg-libjpeg
# Successfully installed pylibjpeg-libjpeg-1.3.1
# Collecting pylibjpeg
#   Downloading pylibjpeg-1.4.0-py3-none-any.whl (28 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from pylibjpeg) (1.21.2)
# Installing collected packages: pylibjpeg
# Successfully installed pylibjpeg-1.4.0

# %%
from fastai.vision.all import *
from fastai.medical.imaging import *
from fastai.imports import *
import warnings
warnings.filterwarnings('ignore')

# %%
path = Path('./New Data/train-Data/train/')

# %%
class PILDicom2(PILBase):
    _open_args,_tensor_cls,_show_args = {},TensorDicom,TensorDicom._show_args
    @classmethod
    def create(cls, fn:(Path,str,bytes), mode=None)->None:
        if isinstance(fn,bytes): 
            im = pydicom.dcmread(pydicom.filebase.DicomBytesIO(fn))
        if isinstance(fn,(Path,str)): 
            im = fn.dcmread()
        scaled = np.array(im.windowed(w=1500, l=-600).numpy())*255
        scaled = scaled.astype(np.uint8)
        return cls(Image.fromarray(scaled))

# %%
dblock = DataBlock(
    blocks=(ImageBlock(cls=PILDicom2), CategoryBlock),
    get_items=get_dicom_files,
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=parent_label,
    item_tfms=[Resize(512)],
    batch_tfms=aug_transforms(size=512)
    )

# %%
dls = dblock.dataloaders(path, bs = 16, num_workers=0)

# %%
dls.train.show_batch(max_n=9, nrows=3)

# %%
len(dls.train_ds), len(dls.valid_ds)
# Out:
# (11378, 2844)

# %%
mixup = MixUp(0.5)

# %%
learn = cnn_learner(dls, resnet50, loss_func=LabelSmoothingCrossEntropy(), metrics=[accuracy, 
                    Precision(), Recall(), F1Score()], cbs = mixup)

# %%
learn.opt_func
# Out:
# <function fastai.optimizer.Adam(params, lr, mom=0.9, sqr_mom=0.99, eps=1e-05, wd=0.01, decouple_wd=True)>

# %%
learn.lr_find()
# Out:
# SuggestedLRs(valley=0.0004786300996784121)

# %%
learn.fine_tune(epochs=1,
          base_lr=0.0004786300996784121,
          cbs=[SaveModelCallback(monitor='f1_score')])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>f1_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.684165</td>
#       <td>0.449371</td>
#       <td>0.851617</td>
#       <td>0.844535</td>
#       <td>0.865692</td>
#       <td>0.854983</td>
#       <td>09:17</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with f1_score value: 0.8549828178694158.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>f1_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.509444</td>
#       <td>0.281733</td>
#       <td>0.959916</td>
#       <td>0.957785</td>
#       <td>0.963118</td>
#       <td>0.960444</td>
#       <td>08:19</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with f1_score value: 0.9604441360166551.

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()

# %%
learn.unfreeze()
learn.fit_one_cycle(n_epoch=4, lr_max=0.0004786300996784121)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>f1_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.569180</td>
#       <td>0.439156</td>
#       <td>0.845992</td>
#       <td>0.825407</td>
#       <td>0.881698</td>
#       <td>0.852624</td>
#       <td>08:17</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.501810</td>
#       <td>0.416987</td>
#       <td>0.851266</td>
#       <td>0.840268</td>
#       <td>0.871260</td>
#       <td>0.855483</td>
#       <td>08:21</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.444014</td>
#       <td>0.263752</td>
#       <td>0.976090</td>
#       <td>0.979678</td>
#       <td>0.972860</td>
#       <td>0.976257</td>
#       <td>08:16</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.428735</td>
#       <td>0.256468</td>
#       <td>0.976090</td>
#       <td>0.979678</td>
#       <td>0.972860</td>
#       <td>0.976257</td>
#       <td>08:18</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_loss()

# %%
learn.recorder.plot_sched(figsize=(15,5))

# %%
learn.show_results(max_n=16,figsize=(20,20))

# %%
test_path = './New Data/test-Data/test/'
test_files = get_dicom_files(test_path)
test_files
# Out:
# (#3406) [Path('New Data/test-Data/test/Negative/2.000000-62502-1-097.dcm'),Path('New Data/test-Data/test/Negative/2.000000-55762-1-023.dcm'),Path('New Data/test-Data/test/Negative/2.000000-57539-1-018.dcm'),Path('New Data/test-Data/test/Negative/2.000000-58080-1-182.dcm'),Path('New Data/test-Data/test/Negative/3.000000-58887-1-108.dcm'),Path('New Data/test-Data/test/Negative/3.000000-56570-1-170.dcm'),Path('New Data/test-Data/test/Negative/3.000000-56570-1-130.dcm'),Path('New Data/test-Data/test/Negative/2.000000-57539-1-162.dcm'),Path('New Data/test-Data/test/Negative/3.000000-60317-1-178.dcm'),Path('New Data/test-Data/test/Negative/3.000000-61865-1-197.dcm')...]

# %%
len(test_files)
# Out:
# 3406

# %%
test_dls = dls.test_dl(test_files, bs = 16, with_labels=True) #holdout set

# %%
test_interp = ClassificationInterpretation.from_learner(learn, dl=test_dls)

# %%
test_interp.print_classification_report()
test_interp.plot_confusion_matrix(figsize=(6,6))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.75      0.70      0.72      2085
#     Positive       0.57      0.63      0.60      1321
#
#     accuracy                           0.67      3406
#    macro avg       0.66      0.66      0.66      3406
# weighted avg       0.68      0.67      0.67      3406

# %%
learn.export()

# %%
learn.predict(Path('New Data/test-Data/test/Negative/2.000000-62502-1-097.dcm'))
# Out:
# ('Negative', TensorBase(0), TensorBase([0.9433, 0.0567]))

# %%
learn.predict(Path('New Data/test-Data/test/Negative/3.000000-61865-1-197.dcm'))
# Out:
# ('Positive', TensorBase(1), TensorBase([0.2841, 0.7159]))

# %%
pos = learn.predict(Path('New Data/test-Data/test/Positive/2.000000-40436-1-001.dcm'))

# %%
pos[0]
# Out:
# 'Negative'

# %%
# checking covid based on average of total images not per image

def covid_check(images_path):
    covid = 0
    no_covid = 0
    patient_images = get_dicom_files(images_path)
    for x in patient_images:
        pred = learn.predict(x)
        if pred[0] == 'Negative':
            no_covid += 1
        else:
            covid += 1
        continue
    if covid > no_covid:
        print('POSITIVE FOR COVID')
    elif covid < no_covid:
        print('NEGATIVE FOR COVID')
    else:
        print('REDO TEST')
    #return covid, no_covid

# %%
test_patient1 = './test-normal/set-A/MIDRC-RICORD-1A-660042-000124'

# %%
covid_check(test_patient1)
# Out:
# POSITIVE FOR COVID

# %%
test_patient2 = './test-normal/set-A/MIDRC-RICORD-1A-660042-000127'
covid_check(test_patient2)
# Out:
# POSITIVE FOR COVID

# %%
test_patient3 = './test-normal/set-A/MIDRC-RICORD-1A-660042-000149'
covid_check(test_patient3)
# Out:
# NEGATIVE FOR COVID

# %%
test_patient4 = './test-normal/set-B/MIDRC-RICORD-1B-660042-000232'
covid_check(test_patient4)
# Out:
# NEGATIVE FOR COVID

# %%
test_patient5 = './test-normal/set-B/MIDRC-RICORD-1B-660042-000256'
covid_check(test_patient5)
# Out:
# NEGATIVE FOR COVID

# %%
# !nvidia-smi
# Out:
# Fri Feb  4 21:33:18 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.91.03    Driver Version: 460.91.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  RTX A4000           Off  | 00000000:00:05.0 Off |                  Off |
# | 41%   49C    P8    17W / 140W |   7881MiB / 16117MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
#import torch
#torch.cuda.empty_cache()
