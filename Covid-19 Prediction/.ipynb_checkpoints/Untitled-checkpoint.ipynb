# %%
import os
from pathlib import Path
from pydicom import dcmread
from pydicom.data import get_testdata_file

# %%
#!pip install pydicom

# %%
import os
#Covid Positive
path =r'E:/Scans/MIDRC-RICORD-1A'
Covid_Pos = []

for root, dirs, files in os.walk(path):
	for file in files:
		Covid_Pos.append(os.path.join(root,file))
for name in Covid_Pos:
    print(name)
# Out:
# E:/Scans/MIDRC-RICORD-1A\MIDRC-RICORD-1A-419639-000421\12-05-2006-CT CHEST WITHOUT CONTRAST-50477\1.000000-Scout-01216\1-1.dcm
# E:/Scans/MIDRC-RICORD-1A\MIDRC-RICORD-1A-419639-000421\12-05-2006-CT CHEST WITHOUT CONTRAST-50477\1.000000-Scout-01216\2-1.dcm
# E:/Scans/MIDRC-RICORD-1A\MIDRC-RICORD-1A-419639-000421\12-05-2006-CT CHEST WITHOUT CONTRAST-50477\2.000000-CHEST WITHOUT CONTRAST-83326\1-001.dcm
# E:/Scans/MIDRC-RICORD-1A\MIDRC-RICORD-1A-419639-000421\12-05-2006-CT CHEST WITHOUT CONTRAST-50477\2.000000-CHEST WITHOUT CONTRAST-83326\1-002.dcm
# E:/Scans/MIDRC-RICORD-1A\MIDRC-RICORD-1A-419639-000421\12-05-2006-CT CHEST WITHOUT CONTRAST-50477\2.000000-CHEST WITHOUT CONTRAST-83326\1-003.dcm
# E:/Scans/MIDRC-RICORD-1A\MIDRC-RICORD-1A-419639-000421\12-05-2006-CT CHEST WITHOUT CONTRAST-50477\2.000000-CHEST WITHOUT CONTRAST-83326\1-004.dcm
# E:/Scans/MIDRC-RICORD-1A\MIDRC-RICORD-1A-419639-000421\12-05-2006-CT CHEST WITHOUT CONTRAST-50477\2.000000-CHEST WITHOUT CONTRAST-83326\1-005.dcm
# ...

# %%
path1 ='E:/Scans/MIDRC-RICORD-1B'
Covid_Neg = []

for root, dirs, files in os.walk(path1):
	for file in files:
		Covid_Neg.append(os.path.join(root,file))
for name in Covid_Neg:
    print(name)
# Out:
# E:/Scans/MIDRC-RICORD-1B\MIDRC-RICORD-1B-419639-001866\12-13-2002-CT CHEST WITHOUT CONTRAST-81408\2.000000-CHEST WITHOUT CONTRAST-36944\1-001.dcm
# E:/Scans/MIDRC-RICORD-1B\MIDRC-RICORD-1B-419639-001866\12-13-2002-CT CHEST WITHOUT CONTRAST-81408\2.000000-CHEST WITHOUT CONTRAST-36944\1-002.dcm
# E:/Scans/MIDRC-RICORD-1B\MIDRC-RICORD-1B-419639-001866\12-13-2002-CT CHEST WITHOUT CONTRAST-81408\2.000000-CHEST WITHOUT CONTRAST-36944\1-003.dcm
# E:/Scans/MIDRC-RICORD-1B\MIDRC-RICORD-1B-419639-001866\12-13-2002-CT CHEST WITHOUT CONTRAST-81408\2.000000-CHEST WITHOUT CONTRAST-36944\1-004.dcm
# E:/Scans/MIDRC-RICORD-1B\MIDRC-RICORD-1B-419639-001866\12-13-2002-CT CHEST WITHOUT CONTRAST-81408\2.000000-CHEST WITHOUT CONTRAST-36944\1-005.dcm
# E:/Scans/MIDRC-RICORD-1B\MIDRC-RICORD-1B-419639-001866\12-13-2002-CT CHEST WITHOUT CONTRAST-81408\2.000000-CHEST WITHOUT CONTRAST-36944\1-006.dcm
# ...
