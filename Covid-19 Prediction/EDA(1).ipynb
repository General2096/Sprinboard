# %%
# !pip install gdcm
# !pip install pylibjpeg
# !pip install pylibjpeg-libjpeg
# !pip install seaborn
# Out:
# Requirement already satisfied: gdcm in /opt/conda/lib/python3.7/site-packages (1.1)
# Requirement already satisfied: pylibjpeg in /opt/conda/lib/python3.7/site-packages (1.4.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from pylibjpeg) (1.21.2)
# Requirement already satisfied: pylibjpeg-libjpeg in /opt/conda/lib/python3.7/site-packages (1.3.1)
# Requirement already satisfied: numpy>=1.20 in /opt/conda/lib/python3.7/site-packages (from pylibjpeg-libjpeg) (1.21.2)
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.7/site-packages (0.11.2)
# Requirement already satisfied: numpy>=1.15 in /opt/conda/lib/python3.7/site-packages (from seaborn) (1.21.2)
# Requirement already satisfied: pandas>=0.23 in /opt/conda/lib/python3.7/site-packages (from seaborn) (1.3.4)
# Requirement already satisfied: matplotlib>=2.2 in /opt/conda/lib/python3.7/site-packages (from seaborn) (3.4.3)
# Requirement already satisfied: scipy>=1.0 in /opt/conda/lib/python3.7/site-packages (from seaborn) (1.7.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.7/site-packages (from pandas>=0.23->seaborn) (2021.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pylibjpeg
import libjpeg

import torch
from fastai.imports import *
from fastai.medical.imaging import *

# %%
metadata = pd.read_json('Covid Data/MIDRC_CT_Scan_metadata.json')
metadata
# Out:
#                                                         submitter_id  \
# 0                             1.2.826.0.1.3680043.10.474.954795.7902
# 1                             1.2.826.0.1.3680043.10.474.660042.1825
# 2                            1.2.826.0.1.3680043.10.474.660042.44037
# 3                            1.2.826.0.1.3680043.10.474.954795.12326
# 4                            1.2.826.0.1.3680043.10.474.660042.48940
# ..                                                               ...
# 82                           1.2.826.0.1.3680043.10.474.660042.53481
# 83                           1.2.826.0.1.3680043.10.474.660042.29997
# 84  1.2.826.0.1.3680043.10.474.419639.691275247246505254912386946200
# 85                            1.2.826.0.1.3680043.10.474.954795.7731
# 86                           1.2.826.0.1.3680043.10.474.954795.10136
#
#     _ct_series_count  _ct_instances_count study_modality  study_description  \
# 0                  1                   87           [CT]                NaN
# 1                  1                  203           [CT]                NaN
# 2                  1                  215           [CT]                NaN
# 3                  1                   89           [CT]                NaN
# 4                  1                  235           [CT]                NaN
# ..               ...                  ...            ...                ...
# 82                 1                  240           [CT]                NaN
# 83                 1                  210           [CT]                NaN
# 84                 8                 1159           [CT]                NaN
# 85                 1                   89           [CT]                NaN
# 86                 1                   98           [CT]                NaN
#
#     age_at_imaging  study_year  study_year_shifted body_part_examined  \
# 0              NaN         NaN                 NaN            [CHEST]
# 1              NaN         NaN                 NaN            [CHEST]
# 2              NaN         NaN                 NaN            [CHEST]
# 3              NaN         NaN                 NaN            [CHEST]
# 4              NaN         NaN                 NaN            [CHEST]
# ..             ...         ...                 ...                ...
# 82             NaN         NaN                 NaN            [CHEST]
# 83             NaN         NaN                 NaN            [CHEST]
# 84             NaN         NaN                 NaN            [CHEST]
# 85             NaN         NaN                 NaN            [CHEST]
# 86             NaN         NaN                 NaN            [CHEST]
#
#     covid19_positive  ...                image_type  lossy_image_compression  \
# 0                NaN  ...                    [None]                       []
# 1                NaN  ...                    [None]                       []
# 2                NaN  ...                    [None]                       []
# 3                NaN  ...                    [None]                       []
# 4                NaN  ...                    [None]                       []
# ..               ...  ...                       ...                      ...
# 82               NaN  ...                    [None]                       []
# 83               NaN  ...                    [None]                       []
# 84               NaN  ...  [None, None, None, None]                       []
# 85               NaN  ...                    [None]                       []
# 86               NaN  ...                    [None]                       []
#
#     manufacturer  manufacturer_model_name  modality  \
# 0             []                       []      [CT]
# 1             []                       []      [CT]
# 2             []                       []      [CT]
# 3             []                       []      [CT]
# 4             []                       []      [CT]
# ..           ...                      ...       ...
# 82            []                       []      [CT]
# 83            []                       []      [CT]
# 84            []                       []      [CT]
# 85            []                       []      [CT]
# 86            []                       []      [CT]
#
#                                        pixel_spacing  \
# 0                                             [None]
# 1                                             [None]
# 2                                             [None]
# 3                                             [None]
# 4                                             [None]
# ..                                               ...
# 82                                            [None]
# 83                                            [None]
# 84  [None, None, None, None, None, None, None, None]
# 85                                            [None]
# 86                                            [None]
#
#                                                                     series_description  \
# 0                                                            [THORAX PE ART AXIAL 3X3]
# 1                                                                                   []
# 2                                                                                   []
# 3                                                            [THORAX PE ART AXIAL 3X3]
# 4                                                                                   []
# ..                                                                                 ...
# 82                                                                                  []
# 83                                                                                  []
# 84  [0.625mm Detail alg, 2.5mm IODINE(WATER), SAG 3X3, PE SCOUT, 1.25 60 KEV, COR 3X3]
# 85                                                           [THORAX PE ART AXIAL 3X3]
# 86                                                             [TAP ART/VEN AXIAL 3X3]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           series_uid  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [1.2.826.0.1.3680043.10.474.954795.7903]
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [1.2.826.0.1.3680043.10.474.660042.1826]
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [1.2.826.0.1.3680043.10.474.660042.44038]
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [1.2.826.0.1.3680043.10.474.954795.12327]
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [1.2.826.0.1.3680043.10.474.660042.48941]
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 82                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         [1.2.826.0.1.3680043.10.474.660042.53482]
# 83                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         [1.2.826.0.1.3680043.10.474.660042.29998]
# 84  [1.2.826.0.1.3680043.10.474.419639.333446818289534784821016786497, 1.2.826.0.1.3680043.10.474.419639.131594059060712105947414811831, 1.2.826.0.1.3680043.10.474.419639.224881984079070203677867208017, 1.2.826.0.1.3680043.10.474.419639.455408098998889976505939918451, 1.2.826.0.1.3680043.10.474.419639.195631182822445808945792598003, 1.2.826.0.1.3680043.10.474.419639.259384151105891625275828843298, 1.2.826.0.1.3680043.10.474.419639.113869758149514128057672769058, 1.2.826.0.1.3680043.10.474.419639.166011720264886300637357651165]
# 85                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [1.2.826.0.1.3680043.10.474.954795.7732]
# 86                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         [1.2.826.0.1.3680043.10.474.954795.10137]
#
#    spatial_resolution      project_id
# 0                  []  TCIA-RICORD-1b
# 1                  []  TCIA-RICORD-1a
# 2                  []  TCIA-RICORD-1b
# 3                  []  TCIA-RICORD-1b
# 4                  []  TCIA-RICORD-1b
# ..                ...             ...
# 82                 []  TCIA-RICORD-1b
# 83                 []  TCIA-RICORD-1a
# 84                 []  TCIA-RICORD-1a
# 85                 []  TCIA-RICORD-1b
# 86                 []  TCIA-RICORD-1b
#
# [87 rows x 33 columns]

# %%
metadata.columns
# Out:
# Index(['submitter_id', '_ct_series_count', '_ct_instances_count',
#        'study_modality', 'study_description', 'age_at_imaging', 'study_year',
#        'study_year_shifted', 'body_part_examined', 'covid19_positive',
#        'age_at_index', 'index_event', 'sex', 'race', 'zip', 'data_format',
#        'acquisition_type', 'convolution_kernel', 'exposure_modulation_type',
#        'patient_position', 'slice_thickness', 'spacing_between_slices',
#        'contrast_bolus_agent', 'image_type', 'lossy_image_compression',
#        'manufacturer', 'manufacturer_model_name', 'modality', 'pixel_spacing',
#        'series_description', 'series_uid', 'spatial_resolution', 'project_id'],
#       dtype='object')

# %%
metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 33 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   submitter_id              87 non-null     object
#  1   _ct_series_count          87 non-null     int64
#  2   _ct_instances_count       87 non-null     int64
#  3   study_modality            87 non-null     object
#  4   study_description         0 non-null      float64
#  5   age_at_imaging            0 non-null      float64
#  6   study_year                0 non-null      float64
#  7   study_year_shifted        0 non-null      float64
#  8   body_part_examined        87 non-null     object
#  9   covid19_positive          0 non-null      float64
#  10  age_at_index              0 non-null      float64
#  11  index_event               0 non-null      float64
#  12  sex                       0 non-null      float64
#  13  race                      0 non-null      float64
#  14  zip                       0 non-null      float64
#  15  data_format               87 non-null     object
#  16  acquisition_type          87 non-null     object
#  17  convolution_kernel        87 non-null     object
#  18  exposure_modulation_type  87 non-null     object
#  19  patient_position          87 non-null     object
#  20  slice_thickness           87 non-null     object
#  21  spacing_between_slices    87 non-null     object
#  22  contrast_bolus_agent      87 non-null     object
#  23  image_type                87 non-null     object
#  24  lossy_image_compression   87 non-null     object
#  25  manufacturer              87 non-null     object
#  26  manufacturer_model_name   87 non-null     object
#  27  modality                  87 non-null     object
#  28  pixel_spacing             87 non-null     object
#  29  series_description        87 non-null     object
#  30  series_uid                87 non-null     object
#  31  spatial_resolution        87 non-null     object
#  32  project_id                87 non-null     object
# dtypes: float64(10), int64(2), object(21)
# memory usage: 22.6+ KB

# %%
#dataset a is covid positive
metadata['Result'] = 'Positive'
metadata['Result'] = np.where((metadata['project_id'] == 'TCIA-RICORD-1b'),'Negative',metadata['Result'])
metadata
# Out:
#                                                         submitter_id  \
# 0                             1.2.826.0.1.3680043.10.474.954795.7902
# 1                             1.2.826.0.1.3680043.10.474.660042.1825
# 2                            1.2.826.0.1.3680043.10.474.660042.44037
# 3                            1.2.826.0.1.3680043.10.474.954795.12326
# 4                            1.2.826.0.1.3680043.10.474.660042.48940
# ..                                                               ...
# 82                           1.2.826.0.1.3680043.10.474.660042.53481
# 83                           1.2.826.0.1.3680043.10.474.660042.29997
# 84  1.2.826.0.1.3680043.10.474.419639.691275247246505254912386946200
# 85                            1.2.826.0.1.3680043.10.474.954795.7731
# 86                           1.2.826.0.1.3680043.10.474.954795.10136
#
#     _ct_series_count  _ct_instances_count study_modality  study_description  \
# 0                  1                   87           [CT]                NaN
# 1                  1                  203           [CT]                NaN
# 2                  1                  215           [CT]                NaN
# 3                  1                   89           [CT]                NaN
# 4                  1                  235           [CT]                NaN
# ..               ...                  ...            ...                ...
# 82                 1                  240           [CT]                NaN
# 83                 1                  210           [CT]                NaN
# 84                 8                 1159           [CT]                NaN
# 85                 1                   89           [CT]                NaN
# 86                 1                   98           [CT]                NaN
#
#     age_at_imaging  study_year  study_year_shifted body_part_examined  \
# 0              NaN         NaN                 NaN            [CHEST]
# 1              NaN         NaN                 NaN            [CHEST]
# 2              NaN         NaN                 NaN            [CHEST]
# 3              NaN         NaN                 NaN            [CHEST]
# 4              NaN         NaN                 NaN            [CHEST]
# ..             ...         ...                 ...                ...
# 82             NaN         NaN                 NaN            [CHEST]
# 83             NaN         NaN                 NaN            [CHEST]
# 84             NaN         NaN                 NaN            [CHEST]
# 85             NaN         NaN                 NaN            [CHEST]
# 86             NaN         NaN                 NaN            [CHEST]
#
#     covid19_positive  ...  lossy_image_compression  manufacturer  \
# 0                NaN  ...                       []            []
# 1                NaN  ...                       []            []
# 2                NaN  ...                       []            []
# 3                NaN  ...                       []            []
# 4                NaN  ...                       []            []
# ..               ...  ...                      ...           ...
# 82               NaN  ...                       []            []
# 83               NaN  ...                       []            []
# 84               NaN  ...                       []            []
# 85               NaN  ...                       []            []
# 86               NaN  ...                       []            []
#
#     manufacturer_model_name  modality  \
# 0                        []      [CT]
# 1                        []      [CT]
# 2                        []      [CT]
# 3                        []      [CT]
# 4                        []      [CT]
# ..                      ...       ...
# 82                       []      [CT]
# 83                       []      [CT]
# 84                       []      [CT]
# 85                       []      [CT]
# 86                       []      [CT]
#
#                                        pixel_spacing  \
# 0                                             [None]
# 1                                             [None]
# 2                                             [None]
# 3                                             [None]
# 4                                             [None]
# ..                                               ...
# 82                                            [None]
# 83                                            [None]
# 84  [None, None, None, None, None, None, None, None]
# 85                                            [None]
# 86                                            [None]
#
#                                                                     series_description  \
# 0                                                            [THORAX PE ART AXIAL 3X3]
# 1                                                                                   []
# 2                                                                                   []
# 3                                                            [THORAX PE ART AXIAL 3X3]
# 4                                                                                   []
# ..                                                                                 ...
# 82                                                                                  []
# 83                                                                                  []
# 84  [0.625mm Detail alg, 2.5mm IODINE(WATER), SAG 3X3, PE SCOUT, 1.25 60 KEV, COR 3X3]
# 85                                                           [THORAX PE ART AXIAL 3X3]
# 86                                                             [TAP ART/VEN AXIAL 3X3]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           series_uid  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [1.2.826.0.1.3680043.10.474.954795.7903]
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [1.2.826.0.1.3680043.10.474.660042.1826]
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [1.2.826.0.1.3680043.10.474.660042.44038]
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [1.2.826.0.1.3680043.10.474.954795.12327]
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [1.2.826.0.1.3680043.10.474.660042.48941]
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 82                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         [1.2.826.0.1.3680043.10.474.660042.53482]
# 83                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         [1.2.826.0.1.3680043.10.474.660042.29998]
# 84  [1.2.826.0.1.3680043.10.474.419639.333446818289534784821016786497, 1.2.826.0.1.3680043.10.474.419639.131594059060712105947414811831, 1.2.826.0.1.3680043.10.474.419639.224881984079070203677867208017, 1.2.826.0.1.3680043.10.474.419639.455408098998889976505939918451, 1.2.826.0.1.3680043.10.474.419639.195631182822445808945792598003, 1.2.826.0.1.3680043.10.474.419639.259384151105891625275828843298, 1.2.826.0.1.3680043.10.474.419639.113869758149514128057672769058, 1.2.826.0.1.3680043.10.474.419639.166011720264886300637357651165]
# 85                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [1.2.826.0.1.3680043.10.474.954795.7732]
# 86                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         [1.2.826.0.1.3680043.10.474.954795.10137]
#
#    spatial_resolution      project_id    Result
# 0                  []  TCIA-RICORD-1b  Negative
# 1                  []  TCIA-RICORD-1a  Positive
# 2                  []  TCIA-RICORD-1b  Negative
# 3                  []  TCIA-RICORD-1b  Negative
# 4                  []  TCIA-RICORD-1b  Negative
# ..                ...             ...       ...
# 82                 []  TCIA-RICORD-1b  Negative
# 83                 []  TCIA-RICORD-1a  Positive
# 84                 []  TCIA-RICORD-1a  Positive
# 85                 []  TCIA-RICORD-1b  Negative
# 86                 []  TCIA-RICORD-1b  Negative
#
# [87 rows x 34 columns]

# %%
TEST_DCM = Path('New Data/train-Data/train/Negative/1.000000-51699-1-001.dcm')
dcm = TEST_DCM.dcmread()
dcm
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 182
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.826.0.1.3680043.10.474.660042.51898
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.3.6.1.4.1.22213.1.143
# (0002, 0013) Implementation Version Name         SH: '0.5'
# (0002, 0016) Source Application Entity Title     AE: 'POSDA'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: ['ISO 2022 IR 101', 'ISO 2022 IR 100']
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL', 'CT_SOM5 SPI']
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.826.0.1.3680043.10.474.660042.51898
# (0008, 0020) Study Date                          DA: '19970909'
# (0008, 0021) Series Date                         DA: '19970909'
# (0008, 0022) Acquisition Date                    DA: '19970909'
# (0008, 0023) Content Date                        DA: '19970909'
# (0008, 002a) Acquisition DateTime                DT: '19970909211447.534000'
# (0008, 0030) Study Time                          TM: '212810.062000'
# (0008, 0031) Series Time                         TM: '211517.750000'
# (0008, 0032) Acquisition Time                    TM: '211447.534000'
# (0008, 0033) Content Time                        TM: '211447.534000'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 0070) Manufacturer                        LO: ''
# (0008, 0090) Referring Physician's Name          PN: ''
# (0010, 0010) Patient's Name                      PN: 'MIDRC-RICORD-1B-660042-000210'
# (0010, 0020) Patient ID                          LO: 'MIDRC-RICORD-1B-660042-000210'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0012, 0063) De-identification Method            LO: 'RSNA Covid-19 Dataset Default'
# (0012, 0064)  De-identification Method Code Sequence  4 item(s) ----
#    (0008, 0100) Code Value                          SH: '113100'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Basic Application Confidentiality Profile'
#    ---------
#    (0008, 0100) Code Value                          SH: '113107'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Longitudinal Temporal Information Modified Dates Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113108'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Patient Characteristics Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113109'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Device Identity Option'
#    ---------
# (0013, 0010) Private Creator                     LO: 'CTP'
# (0013, 1010) Private tag data                    LO: 'MIDRC-RICORD-1B'
# (0013, 1013) Private tag data                    LO: '49171303'
# (0018, 0010) Contrast/Bolus Agent                LO: 'APPLIED'
# (0018, 0015) Body Part Examined                  CS: 'CHEST'
# (0018, 0050) Slice Thickness                     DS: '1.5'
# (0018, 0060) KVP                                 DS: '120.0'
# (0018, 0090) Data Collection Diameter            DS: '500.0'
# (0018, 1020) Software Versions                   LO: 'syngo CT 2011A'
# (0018, 1041) Contrast/Bolus Volume               DS: '0.0'
# (0018, 1044) Contrast/Bolus Total Dose           DS: '0.0'
# (0018, 1049) Contrast/Bolus Ingredient Concentra DS: '0.0'
# (0018, 1100) Reconstruction Diameter             DS: '338.0'
# (0018, 1110) Distance Source to Detector         DS: '1085.6'
# (0018, 1111) Distance Source to Patient          DS: '595.0'
# (0018, 1120) Gantry/Detector Tilt                DS: '0.0'
# (0018, 1130) Table Height                        DS: '168.0'
# (0018, 1140) Rotation Direction                  CS: 'CW'
# (0018, 1150) Exposure Time                       IS: '500'
# (0018, 1151) X-Ray Tube Current                  IS: '547'
# (0018, 1152) Exposure                            IS: '182'
# (0018, 1160) Filter Type                         SH: 'WEDGE_3'
# (0018, 1170) Generator Power                     IS: '38'
# (0018, 1190) Focal Spot(s)                       DS: '1.2'
# (0018, 1210) Convolution Kernel                  SH: 'B31f'
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0018, 9306) Single Collimation Width            FD: 0.6
# (0018, 9307) Total Collimation Width             FD: 38.4
# (0018, 9309) Table Speed                         FD: 115.2
# (0018, 9310) Table Feed per Rotation             FD: 57.6
# (0018, 9311) Spiral Pitch Factor                 FD: 1.5
# (0018, 9313) Data Collection Center (Patient)    FD: [0.330078125, -167.669921875, 111.5]
# (0018, 9318) Reconstruction Target Center (Patie FD: [5.330078125, -167.669921875, 111.5]
# (0018, 9323) Exposure Modulation Type            CS: 'XYZ_EC'
# (0018, 9324) Estimated Dose Saving               FD: 60.125
# (0018, 9345) CTDIvol                             FD: 12.301555933333331
# (0018, 9346)  CTDI Phantom Type Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: '113691'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'IEC Body Dosimetry Phantom'
#    ---------
# (0018, 9352) Calcium Scoring Mass Factor Device  FL: [0.7429999709129333, 0.7789999842643738, 0.8119999766349792]
# (0020, 000d) Study Instance UID                  UI: 1.2.826.0.1.3680043.10.474.660042.51698
# (0020, 000e) Series Instance UID                 UI: 1.2.826.0.1.3680043.10.474.660042.51699
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: '1'
# (0020, 0012) Acquisition Number                  IS: '7'
# (0020, 0013) Instance Number                     IS: '1'
# (0020, 0032) Image Position (Patient)            DS: [-163.669921875, -336.669921875, 111.5]
# (0020, 0037) Image Orientation (Patient)         DS: [1, 0, 0, 0, 1, 0]
# (0020, 0052) Frame of Reference UID              UI: 1.2.826.0.1.3680043.10.474.660042.51700
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 1041) Slice Location                      DS: '111.5'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: [0.66015625, 0.66015625]
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 12
# (0028, 0102) High Bit                            US: 11
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0106) Smallest Image Pixel Value          US: 0
# (0028, 0107) Largest Image Pixel Value           US: 2322
# (0028, 1050) Window Center                       DS: [40, -600]
# (0028, 1051) Window Width                        DS: [400, 1200]
# (0028, 1052) Rescale Intercept                   DS: '-1024.0'
# (0028, 1053) Rescale Slope                       DS: '1.0'
# (0028, 1054) Rescale Type                        LO: 'HU'
# (0028, 1055) Window Center & Width Explanation   LO: ['WINDOW1', 'WINDOW2']
# (7fe0, 0010) Pixel Data                          OW: Array of 524288 elements

# %%
dcm.pixel_array, dcm.pixel_array.shape
# Out:
# (array([[32, 15, 19, ..., 31, 27, 20],
#         [34, 22, 19, ..., 30, 22, 18],
#         [33, 33, 17, ..., 26, 22, 26],
#         ...,
#         [19, 50, 61, ..., 22, 22,  9],
#         [35, 39, 32, ..., 12, 30, 34],
#         [20, 13, 13, ..., 10,  4, 22]], dtype=uint16),
#  (512, 512))

# %%
dcm.show()

# %%
path = Path('./New Data/')
scans = get_dicom_files(path)
print(len(scans))
# Out:
# 17628

# %%
items_train = get_dicom_files('./New Data/train-Data')
items_test = get_dicom_files('./New Data/test-Data')
items = items_train + items_test

# %%
dicom_dataframe = pd.DataFrame.from_dicoms(items)

# %%
print(len(dicom_dataframe.columns))
# Out:
# 140

# %%
for x in dicom_dataframe.columns:
    print(x)
# Out:
# SpecificCharacterSet
# MultiImageType
# ImageType
# ImageType1
# ImageType2
# ImageType3
# SOPClassUID
# SOPInstanceUID
# StudyDate
# SeriesDate
# AcquisitionDate
# ContentDate
# AcquisitionDateTime
# StudyTime
# SeriesTime
# AcquisitionTime
# ContentTime
# AccessionNumber
# Modality
# Manufacturer
# ReferringPhysicianName
# PatientName
# PatientID
# PatientBirthDate
# PatientSex
# DeidentificationMethod
# MultiDeidentificationMethodCodeSequence
# DeidentificationMethodCodeSequence
# DeidentificationMethodCodeSequence1
# DeidentificationMethodCodeSequence2
# DeidentificationMethodCodeSequence3
#
# BodyPartExamined
# SliceThickness
# KVP
# DataCollectionDiameter
# SoftwareVersions
# ReconstructionDiameter
# DistanceSourceToDetector
# DistanceSourceToPatient
# GantryDetectorTilt
# TableHeight
# RotationDirection
# ExposureTime
# XRayTubeCurrent
# Exposure
# FilterType
# GeneratorPower
# FocalSpots
# ConvolutionKernel
# PatientPosition
# SingleCollimationWidth
# TotalCollimationWidth
# TableSpeed
# TableFeedPerRotation
# SpiralPitchFactor
# DataCollectionCenterPatient
# ReconstructionTargetCenterPatient
# ExposureModulationType
# EstimatedDoseSaving
# CTDIvol
# MultiCTDIPhantomTypeCodeSequence
# CTDIPhantomTypeCodeSequence
# CalciumScoringMassFactorDevice
# StudyInstanceUID
# SeriesInstanceUID
# StudyID
# SeriesNumber
# AcquisitionNumber
# InstanceNumber
# MultiImagePositionPatient
# ImagePositionPatient
# ImagePositionPatient1
# ImagePositionPatient2
# MultiImageOrientationPatient
# ImageOrientationPatient
# ImageOrientationPatient1
# ImageOrientationPatient2
# ImageOrientationPatient3
# ImageOrientationPatient4
# ImageOrientationPatient5
# FrameOfReferenceUID
# PositionReferenceIndicator
# SliceLocation
# SamplesPerPixel
# PhotometricInterpretation
# Rows
# Columns
# MultiPixelSpacing
# PixelSpacing
# PixelSpacing1
# BitsAllocated
# BitsStored
# HighBit
# PixelRepresentation
# SmallestImagePixelValue
# LargestImagePixelValue
# MultiWindowCenter
# WindowCenter
# WindowCenter1
# MultiWindowWidth
# WindowWidth
# WindowWidth1
# RescaleIntercept
# RescaleSlope
# RescaleType
# MultiWindowCenterWidthExplanation
# WindowCenterWidthExplanation
# WindowCenterWidthExplanation1
# fname
# img_min
# img_max
# img_mean
# img_std
# img_pct_window
# MultiConvolutionKernel
# ConvolutionKernel1
# StudyDescription
# SeriesDescription
# PatientAge
# ContrastBolusAgent
# ScanOptions
# SpacingBetweenSlices
# ContrastBolusRoute
# MultiFocalSpots
# FocalSpots1
# RevolutionTime
# NumberOfStudyRelatedInstances
# PixelPaddingValue
# MultiSpecificCharacterSet
# SpecificCharacterSet1
# ContrastBolusVolume
# ImageType4
# ImageType5
# ImageType6
# ContrastBolusTotalDose
# ContrastBolusIngredientConcentration
# PatientSize
# PatientWeight
# NominalPercentageOfCardiacPhase

# %%
dicom_dataframe.isna().sum(axis = 0).sort_values(ascending = False)[0:20]
# Out:
# NominalPercentageOfCardiacPhase         17473
# ContrastBolusIngredientConcentration    17429
# ContrastBolusTotalDose                  17429
# PatientWeight                           17355
# PatientSize                             17355
# ImageType6                              16935
# ImageType5                              16935
# ImageType4                              16935
# SpecificCharacterSet1                   16458
# MultiSpecificCharacterSet               16458
# ContrastBolusVolume                     14434
# NumberOfStudyRelatedInstances           14428
# FocalSpots1                             12871
# MultiFocalSpots                         12871
# ContrastBolusRoute                      11884
# ContrastBolusAgent                      11685
# PixelPaddingValue                       11223
# RevolutionTime                          11223
# SpacingBetweenSlices                    11217
# MultiConvolutionKernel                  10776
# dtype: int64

# %%
y1=pd.Series(data=items_train)
y1=y1.apply(lambda x: str(x).split('/')[-2])
y1.value_counts().plot.bar()
plt.title('Training Distributions')
plt.show()

# %%
y2=pd.Series(data=items_test)
y2=y2.apply(lambda x: str(x).split('/')[-2])
y2.value_counts().plot.bar()
plt.title('Testing Distributions')
plt.show()

# %%
metadata['Result'].value_counts()
# Out:
# Negative    54
# Positive    33
# Name: Result, dtype: int64

# %%
sns.displot(data=metadata, x="Result", kde=True, height=2, aspect=3);

# %%
type(dcm)
# Out:
# pydicom.dataset.FileDataset

# %%
dcm.pixels
# Out:
# tensor([[32., 15., 19.,  ..., 31., 27., 20.],
#         [34., 22., 19.,  ..., 30., 22., 18.],
#         [33., 33., 17.,  ..., 26., 22., 26.],
#         ...,
#         [19., 50., 61.,  ..., 22., 22.,  9.],
#         [35., 39., 32.,  ..., 12., 30., 34.],
#         [20., 13., 13.,  ..., 10.,  4., 22.]])

# %%
data_scaled = dcm.hist_scaled()
plt.imshow(data_scaled, cmap=plt.cm.bone);

# %%
data_scaled = dcm.hist_scaled(min_px=100, max_px=1000)
plt.imshow(data_scaled, cmap=plt.cm.bone);

# %%
plt.imshow(dcm.windowed(*dicom_windows.brain), cmap=plt.cm.bone);

# %%
tensor_ct = TensorCTScan(dcm.pixel_array)
tensor_ct.show();
# Out:
# /opt/conda/lib/python3.7/site-packages/torch/overrides.py:1351: DeprecationWarning: Defining your `__torch_function__ as a plain method is deprecated and will be an error in PyTorch 1.11, please define it as a classmethod.
#   DeprecationWarning)

# %%
dcm.show(cmap=plt.cm.gist_ncar, figsize=(6,6))

# %%
import random

rand = random.sample(items_train, 5)
for x in rand:
    dcm = x.dcmread()
    dcm.show()
